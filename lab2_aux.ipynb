# %%
from matplotlib import pyplot as plt
import seaborn as sns


plt.figure(figsize=(6, 6))
sns.heatmap([[1, 2], [1, 0]], annot=True, fmt="d", linewidths=.5, square=True,
            xticklabels=['True', 'False'], yticklabels=['True', 'False'], cmap='magma',)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.title('Confusion matrix - UserID 679', size=15)
plt.gca().xaxis.tick_top()
plt.show()

# %%
from IPython.display import Markdown, display

tp=1
fp=2
fn=1
tn=0

precision = 0.33333333333333*100
recall = 0.5*100
f1 = 0.4*100
support = tp + fp

display(Markdown(
    f"### Resultados con entrenamiento\n\n||**Precision**|**Recall**|**F1**|**Support**|\n|:---:|:---:|:---:|:---:|:---:|\n|**User 679**|{precision:.3f}%|{recall:.3f}%|{f1:.3f}%|{0 if support is None else support:d}|\n"))
# Out:
# ### Resultados con entrenamiento
#
# ||**Precision**|**Recall**|**F1**|**Support**|
# |:---:|:---:|:---:|:---:|:---:|
# |**User 679**|33.333%|50.000%|40.000%|3|
